# %% [markdown]
# ## Section 4. Model Architecture & Training for RQ2
#
# > **_Can the proposed "Pseudo-RGB" enhancement technique yield statistically significant improvements when applied to the leakage-corrected, rigorous baseline established in RQ1?_**
# >

# %% [markdown]
# Load TensorFlow and check GPU availability as pre-flight check.

# %%
import tensorflow as tf
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
# Out:
# 2025-12-16 15:30:20.768699: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-16 15:30:20.775360: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765870220.784744   36237 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765870220.787942   36237 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765870220.795127   36237 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765870220.795140   36237 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765870220.795141   36237 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765870220.795141   36237 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-16 15:30:20.797418: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Get the version of TensorFlow, related version information, and available GPU.

# %%
print("Tensorflow Version: ", tf.__version__)
print(tf.config.list_physical_devices('GPU'))
print("Numbers of GPU Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.list_physical_devices('GPU')

print("Num GPUs Available: ", len(gpus))
for gpu in gpus:
    print("Name:", gpu.name, "; Type:", gpu.device_type)
# Out:
# Tensorflow Version:  2.19.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Numbers of GPU Available:  1
# Num GPUs Available:  1
# Name: /physical_device:GPU:0 ; Type: GPU

# %% [markdown]
# Since the on-prem environment only has 8GB of VRAM,set `mixed_precision` to enable mixed precision training, saving about 40% of VRAM and usually accelerating 4070 training by 40%.

# %%
from tensorflow.keras import mixed_precision

mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# ### Step A. Defining the ResNet-101 Architecture

# %%
from model_factory import build_resnet101

# %% [markdown]
# ### Step B. Read the Dataset Created by the Previous Notebook

# %% [markdown]
# The first step here is to ensure an independent validation set for the training process. The input data is `df_train`, which was already isolated from `df_test` using `sid` in *Section 1*. The operation once again utilizes `GroupShuffleSplit`. Specifically:
#
# 1. The split must occur at the **Subject Level** to satisfy $\text{Subject}_{train\_final} \cap \text{Subject}_{val} = \emptyset$.
# 2. For the split ratio, 90% is used for training weights (`df_train_final`), and 10% is used for hyperparameter tuning and **Early Stopping** (`df_val`).

# %%
import pandas as pd

df_train_final = pd.read_csv('dataset/train_clean.csv')
df_val = pd.read_csv('dataset/val_clean.csv')
df_test = pd.read_csv('dataset/test_clean.csv')

print(f"Loaded Training Set: {len(df_train_final)} images")
print(f"Loaded Validation Set: {len(df_val)} images")
print(f"Held-out Test Set:    {len(df_test)} images") # only for final evaluation
# Out:
# Loaded Training Set: 54480 images
# Loaded Validation Set: 5612 images
# Held-out Test Set:    14884 images

# %% [markdown]
# Before model training process, the class weights should be calculated based on the training dataset.

# %%
from data_loader import get_class_weights, CLASS_MAP

df_rigorous_parent = pd.concat([df_train_final, df_val], axis=0).reset_index(drop=True)
class_weights = get_class_weights(df_rigorous_parent)

print("Class Weights Calculation Result:\n")
for cls_idx, weight in class_weights.items():
    cls_name = [k for k, v in CLASS_MAP.items() if v == cls_idx][0]
    print(f"Class {cls_idx} ({cls_name:<20}): {weight:.4f}")
# Out:
# Class Weights Calculation Result:
#
# Class 0 (non-demented        ): 0.2824
# Class 1 (dementia_very_mild  ): 7.9152
# Class 2 (dementia_mild       ): 3.1574
# Class 3 (dementia_moderate   ): 61.5697

# %% [markdown]
# Currently, to isolate the impact of the splitting strategy, the input enhancement method is fixed to `jet`; considering standard Nvidia graphics cards, the batch size is set to 16.
#
# This notebook runs the specific experiment using **Jet Colormap** independently.
#
# **Methodology:**
# - **Input:** Grayscale MRI
# - **Transformation:** OpenCV Jet Colormap
# - **Model:** ResNet-101 (Freeze BN)
# - **Split:** Subject-level Split (Clean)

# %%
EXPERIMENT_NAME = 'clahe_jet'
BATCH_SIZE = 16
EPOCHS = 20
LEARNING_RATE = 1e-5

# %%
from data_loader import create_dataset, get_class_weights
from execute_and_ploy import run_experiment, plot_history
from rq2_processors import processor_clahe_jet

# %%
train_ds = create_dataset(
    df_train_final,
    batch_size=BATCH_SIZE,
    shuffle=True,
    preprocess_fn=processor_clahe_jet
)

val_ds = create_dataset(
    df_val,
    batch_size=BATCH_SIZE,
    shuffle=False,
    preprocess_fn=processor_clahe_jet
)
# Out:
# I0000 00:00:1765870241.695797   36237 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6058 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
print(f"[{EXPERIMENT_NAME}] Starting execution...")

model, history = run_experiment(
    name=EXPERIMENT_NAME,
    train_ds=train_ds,
    val_ds=val_ds,
    class_weights=class_weights,
    epochs=EPOCHS,
)

plot_history(history, EXPERIMENT_NAME)
# Out:
# [clahe_jet] Starting execution...
# [clahe_jet] Starting new training session...
# Epoch 1/20
# I0000 00:00:1765867148.232853   23648 service.cc:152] XLA service 0x7fb878002950 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765867148.232870   23648 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# 2025-12-16 14:39:09.503591: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1765867154.321357   23648 cuda_dnn.cc:529] Loaded cuDNN version 91002
#    1/1703 ━━━━━━━━━━━━━━━━━━━━ 25:27:58 54s/step - loss: 0.0521 - sparse_categorical_accuracy: 1.0000
# I0000 00:00:1765867186.969107   23648 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.5609 - sparse_categorical_accuracy: 0.9940
# Epoch 1: val_loss improved from None to 4.02848, saving model to models/resnet101_clahe_jet_best.keras
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 316s 154ms/step - loss: 11.0783 - sparse_categorical_accuracy: 0.8991 - val_loss: 4.0285 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 1.0000e-05
# Epoch 2/20
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.2371 - sparse_categorical_accuracy: 0.9964
# Epoch 2: val_loss did not improve from 4.02848
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 226s 132ms/step - loss: 2.1555 - sparse_categorical_accuracy: 0.9556 - val_loss: 4.1132 - val_sparse_categorical_accuracy: 0.1356 - learning_rate: 1.0000e-05
# Epoch 3/20
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: nan - sparse_categorical_accuracy: 0.9659
# Epoch 3: val_loss did not improve from 4.02848
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 226s 133ms/step - loss: nan - sparse_categorical_accuracy: 0.8856 - val_loss: nan - val_sparse_categorical_accuracy: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 4/20
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: nan - sparse_categorical_accuracy: 1.0371e-04
# Epoch 4: val_loss did not improve from 4.02848
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 227s 134ms/step - loss: nan - sparse_categorical_accuracy: 0.0045 - val_loss: nan - val_sparse_categorical_accuracy: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 5/20
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: nan - sparse_categorical_accuracy: 9.7930e-05
# Epoch 5: val_loss did not improve from 4.02848
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 227s 134ms/step - loss: nan - sparse_categorical_accuracy: 0.0045 - val_loss: nan - val_sparse_categorical_accuracy: 0.0000e+00 - learning_rate: 2.0000e-06
# Epoch 6/20
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: nan - sparse_categorical_accuracy: 9.6292e-05
# Epoch 6: val_loss did not improve from 4.02848
# 1703/1703 ━━━━━━━━━━━━━━━━━━━━ 227s 133ms/step - loss: nan - sparse_categorical_accuracy: 0.0045 - val_loss: nan - val_sparse_categorical_accuracy: 0.0000e+00 - learning_rate: 2.0000e-06
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
class_weights_stabilized = {k: min(v, 10.0) for k, v in class_weights.items()}
print("Stabilized Weights for CLAHE:", class_weights_stabilized)

EXPERIMENT_NAME = 'clahe_jet_weights_stabilized'
# Out:
# Stabilized Weights for CLAHE: {0: np.float64(0.28242968867498874), 1: np.float64(7.915173867228662), 2: np.float64(3.157419083648592), 3: 10.0}

# %%
print(f"[{EXPERIMENT_NAME}] Starting execution...")

model, history = run_experiment(
    name=EXPERIMENT_NAME,
    train_ds=train_ds,
    val_ds=val_ds,
    class_weights=class_weights_stabilized,
    epochs=EPOCHS,
)

plot_history(history, EXPERIMENT_NAME)
# Out:
# [clahe_jet_weights_stabilized] Starting execution...
# [clahe_jet_weights_stabilized] Starting new training session...
# Epoch 1/20
# I0000 00:00:1765870262.312378   36357 service.cc:152] XLA service 0x7f34f8001fd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765870262.312394   36357 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# 2025-12-16 15:31:02.959978: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1765870267.754487   36357 cuda_dnn.cc:529] Loaded cuDNN version 91002
#    1/3405 ━━━━━━━━━━━━━━━━━━━━ 42:53:49 45s/step - loss: 0.3023 - sparse_categorical_accuracy: 0.3125
# I0000 00:00:1765870292.744584   36357 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3589 - sparse_categorical_accuracy: 0.9919
# Epoch 1: val_loss improved from None to 5.68393, saving model to models/resnet101_clahe_jet_weights_stabilized_best.keras
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 303s 76ms/step - loss: 3.5440 - sparse_categorical_accuracy: 0.9481 - val_loss: 5.6839 - val_sparse_categorical_accuracy: 0.1219 - learning_rate: 1.0000e-05
# Epoch 2/20
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2442 - sparse_categorical_accuracy: 0.9847
# Epoch 2: val_loss improved from 5.68393 to 4.08194, saving model to models/resnet101_clahe_jet_weights_stabilized_best.keras
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 252s 74ms/step - loss: 1.9733 - sparse_categorical_accuracy: 0.9674 - val_loss: 4.0819 - val_sparse_categorical_accuracy: 0.2978 - learning_rate: 1.0000e-05
# Epoch 3/20
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0457 - sparse_categorical_accuracy: 0.9937
# Epoch 3: val_loss did not improve from 4.08194
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 250s 73ms/step - loss: 0.3070 - sparse_categorical_accuracy: 0.9887 - val_loss: 4.5163 - val_sparse_categorical_accuracy: 0.3432 - learning_rate: 1.0000e-05
# Epoch 4/20
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9943
# Epoch 4: val_loss improved from 4.08194 to 1.79422, saving model to models/resnet101_clahe_jet_weights_stabilized_best.keras
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 249s 73ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9958 - val_loss: 1.7942 - val_sparse_categorical_accuracy: 0.7099 - learning_rate: 1.0000e-05
# Epoch 5/20
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0011 - sparse_categorical_accuracy: 0.9996
# Epoch 5: val_loss did not improve from 1.79422
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 248s 73ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9982 - val_loss: 2.5824 - val_sparse_categorical_accuracy: 0.6055 - learning_rate: 1.0000e-05
# Epoch 6/20
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9981
# Epoch 6: val_loss did not improve from 1.79422
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 249s 73ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9984 - val_loss: 2.2861 - val_sparse_categorical_accuracy: 0.6246 - learning_rate: 1.0000e-05
# Epoch 7/20
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9990
# Epoch 7: val_loss did not improve from 1.79422
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 249s 73ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9984 - val_loss: 2.4365 - val_sparse_categorical_accuracy: 0.6675 - learning_rate: 1.0000e-05
# Epoch 8/20
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0015 - sparse_categorical_accuracy: 0.9985
# Epoch 8: val_loss did not improve from 1.79422
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 248s 73ms/step - loss: 0.0011 - sparse_categorical_accuracy: 0.9996 - val_loss: 2.6598 - val_sparse_categorical_accuracy: 0.6363 - learning_rate: 2.0000e-06
# Epoch 9/20
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9987
# Epoch 9: val_loss did not improve from 1.79422
# 3405/3405 ━━━━━━━━━━━━━━━━━━━━ 249s 73ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9996 - val_loss: 2.8211 - val_sparse_categorical_accuracy: 0.6461 - learning_rate: 2.0000e-06
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %% [markdown]
# It can be observed that at the 10th epoch, which was the optimal condition, the **Training Accuracy reached 99.96%**, but the **Validation Accuracy only stayed at 65.72%**. This means there is a gap of 34.24% between the two. This confirms that the model is almost incapable of making effective inferences on unseen patients. In other words, under the strict adherence to Subject-level Independence, the **Bayes Error Rate for this classification task is far greater than 0%**.

# %% [markdown]
# 1. **Quantitative Comparison**
#
#     Using the same ResNet-101 model architecture, hyperparameters, and preprocessing pipeline, merely changing the data splitting method resulted in an **inflated validation accuracy**.
#
#     | **Experiment** | **Split Strategy** | **i.i.d. Assumption** | **Leakage Ratio** | **Val Accuracy (min loss)** | **Statistical Interpretation** |
#     | --- | --- | --- | --- | --- | --- |
#     | **Rigorous Baseline** | Subject-level | Valid | 0% | **69.42%** | True Generalization Capability |
#     | **Flawed Baseline** | Slice-level | Violated | **100%** | **100%** | Memorization / Inflation |
#
#     The **data leakage** led to a model performance inflation (or overestimation) as high as **30.58%**.
#
# 2. **Conclusion of RQ1**
#
#     This experiment confirms the argument by **Wen et al. (2020)** that the high accuracies ($>99\%$) commonly seen on datasets like Kaggle or OASIS do not stem from the model learning pathological features, but are rather a statistical artifact caused by the **Lack of Subject-level Independence**.
#
#     The only explanation for the inflated accuracy is that the model is doing Re-identification, rather than Disease Classification.
#
#     The **69.42% accuracy of the Strict Baseline** represents the true lower bound of the ResNet-101 model's actual performance in a realistic clinical setting when dealing with unseen patients. This conclusion also provides a comparable baseline with room for improvement for the subsequent feature augmentation experiments in RQ2.
